# %%
import numpy as np
from useful import *

# %%
def lighttime(t,v,Sepoch=J2016()):
    """Calculate the light time correction for a given time and velocity.
    
    Parameters
    ----------
    t : array
        measurement timestamps in JD
    v : array_like
        radial velocity in km/s
    Sepoch : float, optional
        Reference epoch in Julian years. Default is J2016.
    
    Returns
    -------
    float
        Light time correction in years.
    """
    return light_time_correction
