# %%
import ExTRA as ex
from astropy.io import fits
from astropy.time import Time
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.optimize import minimize
# Out:
# ExTRA  imported correctly

# %%
# Out:
# #
#
# #   is part of this source code package. No part of the package, including
#
# #   the terms contained in the file ‘LICENCE.txt’.
#
#  20114916805338633 2 2456958.111034  146.696 0.231  0.70827991  -59.04677105 0
#
#  20114916805338633 4 2456958.111156  146.557 0.151  0.70828015  -59.04686711 0
#
#  20114916805338633 6 2456958.111259  146.374 0.088  0.70828027  -59.04694869 0
#
#  20114916805338633 8 2456958.111372  146.060 0.100  0.70828044  -59.04703723 1
#
#  20119009095238725 1 2456958.184993  146.244 0.364  0.70847327  -59.11055165 0
#
#  20119009095238725 3 2456958.185105  146.192 0.267  0.70847368  -59.11065699 0
#
#  20119009095238725 5 2456958.185218  146.047 0.273  0.70847410  -59.11076223 0
#
#  20119009095238725 7 2456958.185330  146.023 0.177  0.70847452  -59.11086742 0
#
#  22150086612000799 1 2456994.910525  379.996 0.446 -0.46657142   -5.11437719 0
#
#  22150086612000799 3 2456994.910638  379.977 0.336 -0.46656680   -5.11481035 0
#
#  22150086612000799 5 2456994.910750  380.269 0.174 -0.46656218   -5.11524377 0
#
#  22150086612000799 7 2456994.910863  380.388 0.190 -0.46655756   -5.11567707 0
#
#  22159827441309232 2 2456995.086698  379.200 0.402 -0.45946044   -5.78305060 0
#
#  22159827441309232 4 2456995.086810  379.065 0.246 -0.45945606   -5.78346521 0
#
#  22159827441309232 6 2456995.086932  378.929 0.089 -0.45945132   -5.78391321 0
#
#  22159827441309232 8 2456995.087044  378.508 0.181 -0.45944694   -5.78432791 0
#
#  22163919699111981 1 2456995.160659  378.282 0.231 -0.45646867   -6.06432658 0
#
#  22163919699111981 3 2456995.160771  378.248 0.181 -0.45646396   -6.06476526 0
#
#  22163919699111981 5 2456995.160884  378.292 0.165 -0.45645928   -6.06520450 0
#
#  22163919699111981 7 2456995.160996  378.527 0.154 -0.45645460   -6.06564381 0
#
#  22163919699111981 9 2456995.161108  378.279 0.163 -0.45644990   -6.06608264 0
#
#  22989619581449144 2 2457010.091451   74.947 0.211  0.19659302  -68.57978978 0
#
#  22989619581449144 4 2457010.091564   74.643 0.131  0.19659674  -68.58023238 0
#
#  22989619581449144 6 2457010.091676   74.727 0.094  0.19660047  -68.58067449 0
#
#  22989619581449144 8 2457010.091789   74.620 0.170  0.19660418  -68.58111654 0
#
#  22993711812243969 1 2457010.165414   72.536 0.230  0.19912666  -68.87808924 0
#
#  22993711812243969 3 2457010.165527   72.654 0.182  0.19913062  -68.87855233 0
#
#  22993711812243969 5 2457010.165639   72.911 0.166  0.19913459  -68.87901515 0
#
#  22993711812243969 7 2457010.165752   72.862 0.156  0.19913855  -68.87947801 0
#
#  22993711812243969 9 2457010.165864   72.736 0.165  0.19914252  -68.87994134 0
#
#  23003452565238101 2 2457010.341611   67.960 0.147  0.20515008  -69.59022443 0
#
#  23003452565238101 4 2457010.341724   67.997 0.130  0.20515376  -69.59066728 0
#
#  23003452565238101 6 2457010.341836   68.146 0.150  0.20515746  -69.59111059 0
#
# 112765863248582085 4 2458633.662857  278.478 0.224 -0.50650924  178.61052067 0
#
# 112765863248582085 6 2458633.662970  278.526 0.233 -0.50651282  178.61075175 0
#
# 112765863248582085 8 2458633.663082  278.475 0.237 -0.50651640  178.61098278 0
#
# 120150603084362450 1 2458767.208160 -311.529 0.213 -0.69516230   40.01503304 0
#
# 120150603084362450 3 2458767.208267 -311.561 0.121 -0.69516140   40.01488628 0
#
# 120150603084362450 5 2458767.208385 -311.454 0.139 -0.69516039   40.01472353 0
#
# 120150603084362450 7 2458767.208498 -311.690 0.145 -0.69515949   40.01456877 0
#
# 120150603084362450 9 2458767.208610 -311.363 0.141 -0.69515854   40.01441394 0
#
# 120154695354738568 2 2458767.282212 -311.808 0.180 -0.69446486   39.90567945 0
#
# 120154695354738568 4 2458767.282324 -311.681 0.230 -0.69446367   39.90550204 0
#
# 120154695354738568 6 2458767.282436 -311.457 0.214 -0.69446248   39.90532480 0
#
# 120154695354738568 8 2458767.282549 -311.653 0.227 -0.69446129   39.90514750 0
#
# 121996985218154856 1 2458800.593678  -62.745 0.249  0.64776582  -66.57458202 0
#
# 121996985218154856 3 2458800.593788  -62.668 0.167  0.64776289  -66.57444393 0
#
# 121996985218154856 5 2458800.593900  -62.512 0.266  0.64775997  -66.57430172 0
#
# 121996985218154856 7 2458800.594013  -62.695 0.180  0.64775699  -66.57415867 0
#
# 123021279765127764 1 2458819.114892 -357.213 0.159 -0.49230605   -2.44750553 0
#
# 123021279765127764 3 2458819.115000 -357.030 0.166 -0.49230966   -2.44726482 0
#
# 123021279765127764 5 2458819.115112 -357.176 0.138 -0.49231341   -2.44701435 0
#
# 123021279765127764 7 2458819.115225 -356.959 0.171 -0.49231714   -2.44676503 0
#
# 123021279765127764 9 2458819.115337 -357.034 0.156 -0.49232087   -2.44651680 0

# %%
GAIA_EPOCH=Time('2017.5', format='jyear',scale="tcb")
GAIA_EPOCH_JY=GAIA_EPOCH.jyear
GAIA_EPOCH_JD=GAIA_EPOCH.jd

m1_MS = 0.76  # Primary star mass from paper Table 3;not important

bh3_ra_deg = 294.8278502411 # Right Ascension from paper Table 2
bh3_dec_deg = 14.9309190720 # Declination from paper Table 2


#Gaia Single Star Solution, stolen from git bh3
#the single star solution should always be given in DR4 , as with HIP
g_asc=bh3_ra_deg
g_dec=bh3_dec_deg
g_par=1.68 #mas
g_mua=-30.29679
g_mud=-148.62246
g_stand=np.array([g_asc,g_dec,g_par,g_mua,g_mud])

# %%
#read
rvdata=fits.open("data/GaiaBH3/bh3rv.fit")[1].data
astrodata=fits.open("data/GaiaBH3/bh3ast.fit")[1].data
#header
rv_names=rvdata.names[1:]
ast_names=astrodata.names

# %%
ast=[]
for name in ast_names:
    ast.append(astrodata.field(name))
ast=np.array(ast)
msk=ast[-1]==0
ast=np.array([row[msk] for row in ast])



rv=[]
for name in rv_names:
    rv.append(rvdata.field(name))
rv=np.array(rv)

# %%
plt.scatter(rv[0],rv[1],c="k")
plt.grid()

# %% [markdown]
# # Pre RV fit

# %%
def RV_fit(theta,data):

    v0,K,P,e,om,T0=theta

    t,d,err=data

    L=ex.L_RVs(t,d,err,0,v0,K,P,e,om,T0)
    return L

# %%
x0_rv=(-360,50,3850,0.5,0,GAIA_EPOCH_JD)
bnds_rv=(-500,500),(50,200),(3000,5000),(0,0.8),(-np.pi,np.pi),(GAIA_EPOCH_JD-10000,GAIA_EPOCH_JD+10000)
rvfit=minimize(RV_fit,x0_rv,args=(rv),bounds=bnds_rv,options={"maxiter":1e10},tol=1e-15)
print("v0,K,P,e,om,T0 : \n",rvfit.x)
print(rvfit.fun)
# Out:
# v0,K,P,e,om,T0 :
#  [-3.59261394e+02  5.75987122e+01  4.89401896e+03  7.68455814e-01
#   1.30067567e+00  2.45815153e+06]
# 29.256838442968345

# %%
t_rvmod=np.linspace(rv[0][0],rv[0][-1],1000)
rv_check=ex.RV_mod(*rvfit.x,t_rvmod)
plt.plot(t_rvmod,rv_check,c="r")
plt.scatter(rv[0],rv[1],c="k")
plt.grid()
plt.show()

# %% [markdown]
# # Astrometric fit

# %%
relative_time=Time(ast[0], format='jd', scale='tcb').jyear-GAIA_EPOCH.jyear #not important for fits, just nice for plots

gaia,t_gaia=ex.gaia_init(ast)
A3,A4,A5,A6,A7,A8,A9=gaia

# %%
g_sss=ex.standard_model(*g_stand,t_gaia,ex.earth_position(t_gaia),tangential=True,Sepoch=GAIA_EPOCH_JD)

# %%
planet_residual=ex.abs_res(gaia[-2],g_stand,np.array([g_asc,g_dec,0,0,0]),gaia)

# %%
j=len(planet_residual)
printdata = np.column_stack((np.zeros(j),np.zeros(j),ast[0],ast[1],ast[2],ast[3],ast[4],ast[5]))

# Save to .dat file
np.savetxt("BH3_mod.dat", printdata, fmt="%.6f")

# %%
planet_residual=ex.abs_res(gaia[-2],g_stand,np.array([g_asc,g_dec,0,0,0]),gaia)

res_astrometric=np.copy(gaia)
res_astrometric[-2]=planet_residual

testing=ex.hip_2d(res_astrometric)


ex.plot_hip(*testing)

plt.grid()

# %%
#function you want to miniize
def gaia_min(theta,gaia_ad):

    P,e,om,i,Om,T0,a,del_asc,del_dec,del_para,del_mua,del_mud=theta
    #print(theta)

    correction=del_asc,del_dec,del_para,del_mua,del_mud

    L=ex.L_gaia(gaia_ad,correction,P,e,om,i,Om,T0,a)


    return L

# %% [markdown]
# 4235.8 day
# Eccentricity = 0.728
# omega = 77.9 deg
# Inclination  110.6 deg
# OMEGA = 136.2 deg
# T_periastron = 53941.2 day

# %%
P_g=4235.8
e_g=0.728
om_g=np.radians(77.9)
i_g=np.radians(110.6)
Om_g=np.radians(136.2)
T0_g=GAIA_EPOCH_JD
a_g=27.303
#guess
orb=np.array([P_g,e_g,om_g,i_g,Om_g,T0_g,a_g])
stand_corr=np.array([-6,3,0,0,0])
x0=np.concatenate([orb,stand_corr])

# %%
#bounds
orbbnds=(P_g-100,P_g+100),(0,0.95),(-np.pi,np.pi),(0,2*np.pi),(-np.pi,np.pi),(T0_g-10000,T0_g+10000),(0,100)
standbnds=(-10,10),(-10,10),(-10,10),(-10,10),(-10,10)
bnds=orbbnds+standbnds

# %%
fit=minimize(gaia_min,x0,args=(res_astrometric),bounds=bnds,tol=1e-10,method="Nelder-mead",options={"maxiter":1e5})
print(fit)
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -390.8744421622821
#              x: [ 4.155e+03  7.243e-01  1.358e+00  1.931e+00  2.376e+00
#                   2.458e+06  2.690e+01  4.289e+00  2.371e+00  8.965e-04
#                   1.916e+00 -6.487e+00]
#            nit: 17604
#           nfev: 23916
#  final_simplex: (array([[ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00],
#                        [ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00],
#                        ...,
#                        [ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00],
#                        [ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00]], shape=(13, 12)), array([-3.909e+02, -3.909e+02, ..., -3.909e+02, -3.909e+02],
#                       shape=(13,)))

# %%
fit_residuals=ex.abs_res(planet_residual,fit.x[-5:],np.zeros(5),gaia[:5])

A3=gaia[0]
A4=gaia[1]

x_O,y_O=ex.orbit(*fit.x[:7],t_gaia)
    
res_gaia_final=fit_residuals-(A3*x_O+A4*y_O)

check=ex.res_to_orbit_gaia(res_gaia_final,gaia, fit.x[:7])


#ex.plot_hip(*ex.hip_2d(checking))

plt.title("residuals")
plt.ylabel("DEC[mas]")
plt.xlabel("RA[mas]")
plt.scatter(0,0,c="k",marker="x")

ex.plot_hip(*check)
plt.plot(*ex.orbit(*fit.x[:7],t_rvmod),c="k")



plt.gca().invert_xaxis()
plt.axis("equal")
plt.grid()

# %%
fig,axs=plt.subplots(2,1,sharex=True)
fig.subplots_adjust(hspace=0)


axs[0].scatter(relative_time,fit_residuals,c="k")
axs[0].axhline(0,linestyle="--")
axs[0].set_title("along-scan offset and residuals")
axs[0].set_ylabel("offset[mas]")
axs[0].grid()



axs[1].scatter(relative_time,res_gaia_final,c="r")
axs[1].errorbar(relative_time,res_gaia_final,gaia[-1],c="k",linestyle="",capsize=2)
axs[1].axhline(0,linestyle="--")
axs[1].set_ylabel("O-C[mas]")
axs[1].set_xlabel("epoch-2017[yr]")
axs[1].grid()


#plt.tight_layout()
plt.savefig("pics/bh3res")
plt.show()

# %% [markdown]
# # Combined fit of RVs and Gaia astrometry

# %%
def L_gaia_rv(theta,rvs,gaia_ad,gaia_stand):
    P,e,om,i,Om,T0,a=theta[:7]
    correction=theta[7:12]
    v0=theta[-1]

    t,data,err=rvs




    c_parallax=gaia_stand[2]+correction[2]

    

    Lg=ex.L_gaia(gaia_ad,correction, P, e, om, i, Om, T0, a)

    Lr=ex.L_RVs_comb(t, data, err, 0,v0, P, e, om, i, T0, a, c_parallax)
    
    

    return Lg+Lr

# %%
#units

rvmod=np.copy(rv)
rvmod[1:]=rvmod[1:]*1000

v0_g=np.array([-359.26*1000])
testtheta=np.concatenate((fit.x,v0_g))

# %%
#bounds
orbbnds=(P_g-100,P_g+100),(0,0.95),(-np.pi,np.pi),(0,2*np.pi),(-np.pi,np.pi),(T0_g-10000,T0_g+10000),(0,100)
standbnds=(-10,10),(-10,10),(-10,10),(-10,10),(-10,10)
v0_bnds=(v0_g-1e5,v0_g+1e5),
bnds=orbbnds+standbnds+v0_bnds

# %%
fitlol=minimize(L_gaia_rv,testtheta,args=(rvmod,res_astrometric,g_stand),bounds=bnds,tol=1e-10,method="Nelder-mead",options={"maxiter":1e5})
print(fitlol)
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -243.36518436534377
#              x: [ 4.211e+03  7.270e-01 ... -6.549e+00 -3.572e+05]
#            nit: 6755
#           nfev: 9424
#  final_simplex: (array([[ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05],
#                        [ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05],
#                        ...,
#                        [ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05],
#                        [ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05]], shape=(14, 13)), array([-2.434e+02, -2.434e+02, ..., -2.434e+02, -2.434e+02],
#                       shape=(14,)))

# %%
print(fitlol.x)
print("om,i,Om",np.degrees(fitlol.x[2:5]))
# Out:
# [ 4.21061539e+03  7.27011179e-01  1.35812232e+00  1.93058047e+00
#   2.37697897e+00  2.45817735e+06  2.71713814e+01  4.27971909e+00
#   2.40163736e+00  3.57141937e-03  1.94782559e+00 -6.54858181e+00
#  -3.57210590e+05]
# om,i,Om [ 77.81467711 110.61411298 136.19086271]

# %%
rvcombined=ex.RV_comb(fitlol.x[-1],*fitlol.x[:4],*fitlol.x[5:7],g_stand[2],t_rvmod)

# %%
plt.plot(t_rvmod,rvcombined,c="k")
plt.scatter(rv[0],rv[1]*1000,c="r")
plt.errorbar(rv[0],rv[1]*1000,rv[2]*1000,linestyle="",c="k")
plt.axhline(fitlol.x[-1],c="b",linestyle="--")
plt.grid()
plt.show()

# %%
t_gmod=np.linspace(t_gaia[0],t_gaia[-1],1000)


fit_residuals=ex.abs_res(planet_residual,fitlol.x[-6:-1],np.zeros(5),gaia)

x_O,y_O=ex.orbit(*fitlol.x[:7],t_gaia)
    
res_gaia_final=fit_residuals-(A3*x_O+A4*y_O)

check=ex.res_to_orbit_gaia(res_gaia_final,gaia, fitlol.x[:7])


#ex.plot_hip(*ex.hip_2d(checking))

plt.title("BH3 orbit")
plt.ylabel("DEC[mas]")
plt.xlabel("RA[mas]")
plt.scatter(0,0,c="k",marker="x")

plt.plot(*ex.orbit(*fitlol.x[:7],t_gmod),c="k")


ex.plot_hip(*check)



plt.gca().invert_xaxis()
plt.axis("equal")
plt.grid()

plt.savefig("pics/BH3_orb")

# %%
fig,axs=plt.subplots(2,1,sharex=True)
fig.subplots_adjust(hspace=0)

axs[0].set_title("BH3 orbit (with errors!)")
axs[0].set_ylabel("RA[mas]")
axs[0].scatter(t_gaia,check[0],c="r")
axs[0].errorbar(t_gaia,check[0],abs(check[1]),linestyle="",ecolor="k",capsize=2)
axs[0].plot(t_gmod,ex.orbit(*fitlol.x[:7],t_gmod)[0],linestyle="--",c="k")

axs[0].grid()


axs[1].set_ylabel("DEC[mas]")
axs[1].set_xlabel("t[JD]")
axs[1].scatter(t_gaia,check[2],c="r")
axs[1].errorbar(t_gaia,check[2],abs(check[3]),linestyle="",ecolor="k",capsize=2)
axs[1].plot(t_gmod,ex.orbit(*fitlol.x[:7],t_gmod)[1],linestyle="--",c="k")

plt.grid()
plt.savefig("pics/bh3_1d")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 len(t_gaia)
#
# NameError: name 't_gaia' is not defined
