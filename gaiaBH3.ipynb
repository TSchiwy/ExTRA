# %%
import ExTRA as ex
from astropy.io import fits
from astropy.time import Time
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.optimize import minimize

# %%
GAIA_EPOCH=Time('2017.5', format='jyear',scale="tcb")
GAIA_EPOCH_JY=GAIA_EPOCH.jyear
GAIA_EPOCH_JD=GAIA_EPOCH.jd

m1_MS = 0.76  # Primary star mass from paper Table 3;not important

bh3_ra_deg = 294.8278502411 # Right Ascension from paper Table 2
bh3_dec_deg = 14.9309190720 # Declination from paper Table 2


#Gaia Single Star Solution, stolen from git bh3
#the single star solution should always be given in DR4 , as with HIP
g_asc=bh3_ra_deg
g_dec=bh3_dec_deg
g_par=1.68 #mas
g_mua=-30.29679
g_mud=-148.62246
g_stand=np.array([g_asc,g_dec,g_par,g_mua,g_mud])

# %%
#read
rvdata=fits.open("data/GaiaBH3/bh3rv.fit")[1].data
astrodata=fits.open("data/GaiaBH3/bh3ast.fit")[1].data
#header
rv_names=rvdata.names[1:]
ast_names=astrodata.names

# %%
ast=[]
for name in ast_names:
    ast.append(astrodata.field(name))
ast=np.array(ast)
msk=ast[-1]==0
ast=np.array([row[msk] for row in ast])



rv=[]
for name in rv_names:
    rv.append(rvdata.field(name))
rv=np.array(rv)

# %% [markdown]
# # Pre RV fit

# %%
def RV_fit(theta,data):

    v0,K,P,e,om,T0=theta

    t,d,err=data

    L=ex.L_RVs(t,d,err,0,v0,K,P,e,om,T0)
    return L

# %%
x0_rv=(-360,50,3850,0.5,0,GAIA_EPOCH_JD)
bnds_rv=(-500,500),(50,200),(3000,5000),(0,0.8),(-np.pi,np.pi),(GAIA_EPOCH_JD-10000,GAIA_EPOCH_JD+10000)
rvfit=minimize(RV_fit,x0_rv,args=(rv),bounds=bnds_rv,options={"maxiter":1e10},tol=1e-15)
print("v0,K,P,e,om,T0 : \n",rvfit.x)
print(rvfit.fun)
# Out:
# v0,K,P,e,om,T0 :
#  [-3.59261394e+02  5.75987122e+01  4.89401896e+03  7.68455814e-01
#   1.30067567e+00  2.45815153e+06]
# 29.256838442968345

# %%
t_rvmod=np.linspace(rv[0][0],rv[0][-1],1000)
rv_check=ex.RV_mod(*rvfit.x,t_rvmod)
plt.plot(t_rvmod,rv_check,c="r")
plt.scatter(rv[0],rv[1],c="k")
plt.grid()
plt.show()

# %% [markdown]
# # Astrometric fit

# %%
relative_time=Time(ast[0], format='jd', scale='tcb').jyear-GAIA_EPOCH.jyear #not important for fits, just nice for plots

gaia,t_gaia=ex.gaia_init(ast)
A3,A4,A5,A6,A7,A8,A9=gaia

# %%
g_sss=ex.standard_model(*g_stand,t_gaia,ex.earth_position(t_gaia),tangential=True,Sepoch=GAIA_EPOCH_JD)

# %%
planet_residual=ex.abs_res(gaia[-2],g_stand,np.array([g_asc,g_dec,0,0,0]),gaia)

# %%
planet_residual
# Out:
# array([ 10.65747194,  10.28777681,  10.27708205,  10.14943589,
#          9.98869142,   9.96699568,  10.02934882,   9.84995544,
#         10.27240843,  10.17673097,  10.22112811,  10.30048793,
#         -7.14300299,  -7.13492776,  -7.25065394,  -7.01338057,
#         -7.12310743,  -7.19283433,  -6.8985614 ,  -7.02928797,
#         -7.09401484,  -7.02974169,  10.14960232,  10.06602088,
#         10.22746254,   9.972905  ,  10.38434815,  10.12879321,
#         10.20223909,  10.04668572,  -0.84968344,  -0.83048248,
#         -0.66626229,  -0.86304304,  -0.81182423,  -0.84660593,
#         -0.59438758,  -0.90117004,  -0.66895303])

# %%
j=len(planet_residual)
printdata = np.column_stack((np.zeros(j),np.zeros(j),ast[0],ast[1],ast[2],ast[3],ast[4],ast[5]))

# Save to .dat file
np.savetxt("BH3_mod.dat", printdata, fmt="%.6f")

# %%
planet_residual=ex.abs_res(gaia[-2],g_stand,np.array([g_asc,g_dec,0,0,0]),gaia)

res_astrometric=np.copy(gaia)
res_astrometric[-2]=planet_residual

testing=ex.hip_2d(res_astrometric)


ex.plot_hip(*testing)

plt.grid()

# %%
#function you want to miniize
def gaia_min(theta,gaia_ad):

    P,e,om,i,Om,T0,a,del_asc,del_dec,del_para,del_mua,del_mud=theta
    #print(theta)

    correction=del_asc,del_dec,del_para,del_mua,del_mud

    L=ex.L_gaia(gaia_ad,correction,P,e,om,i,Om,T0,a)


    return L

# %% [markdown]
# 4235.8 day
# Eccentricity = 0.728
# omega = 77.9 deg
# Inclination  110.6 deg
# OMEGA = 136.2 deg
# T_periastron = 53941.2 day

# %%
P_g=4235.8
e_g=0.728
om_g=np.radians(77.9)
i_g=np.radians(110.6)
Om_g=np.radians(136.2)
T0_g=GAIA_EPOCH_JD
a_g=27.303
#guess
orb=np.array([P_g,e_g,om_g,i_g,Om_g,T0_g,a_g])
stand_corr=np.array([-6,3,0,0,0])
x0=np.concatenate([orb,stand_corr])

# %%
#bounds
orbbnds=(P_g-100,P_g+100),(0,0.95),(-np.pi,np.pi),(0,2*np.pi),(-np.pi,np.pi),(T0_g-10000,T0_g+10000),(0,100)
standbnds=(-10,10),(-10,10),(-10,10),(-10,10),(-10,10)
bnds=orbbnds+standbnds

# %%
fit=minimize(gaia_min,x0,args=(res_astrometric),bounds=bnds,tol=1e-10,method="Nelder-mead",options={"maxiter":1e5})
print(fit)
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -390.8744421622821
#              x: [ 4.155e+03  7.243e-01  1.358e+00  1.931e+00  2.376e+00
#                   2.458e+06  2.690e+01  4.289e+00  2.371e+00  8.965e-04
#                   1.916e+00 -6.487e+00]
#            nit: 17604
#           nfev: 23916
#  final_simplex: (array([[ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00],
#                        [ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00],
#                        ...,
#                        [ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00],
#                        [ 4.155e+03,  7.243e-01, ...,  1.916e+00,
#                         -6.487e+00]], shape=(13, 12)), array([-3.909e+02, -3.909e+02, ..., -3.909e+02, -3.909e+02],
#                       shape=(13,)))

# %%
fit_residuals=ex.abs_res(planet_residual,fit.x[-5:],np.zeros(5),res_astrometric[:5])

A3=gaia[0]
A4=gaia[1]

x_O,y_O=ex.orbit(*fit.x[:7],t_gaia)
    
res_gaia_final=fit_residuals-(A3*x_O+A4*y_O)

residual_to_orbit=ex.res_to_orbit_gaia(res_gaia_final,res_astrometric, fit.x[:7])


#ex.plot_hip(*ex.hip_2d(residual_to_orbiting))

plt.title("residuals")
plt.ylabel("DEC[mas]")
plt.xlabel("RA[mas]")
plt.scatter(0,0,c="k",marker="x")

ex.plot_hip(*residual_to_orbit)
plt.plot(*ex.orbit(*fit.x[:7],t_rvmod),c="k")



plt.gca().invert_xaxis()
plt.axis("equal")
plt.grid()

# %%
plt.figure(figsize=(10,2))
plt.scatter(relative_time,fit_residuals,c="k")
plt.axhline(0,linestyle="--")
plt.title("along-scan offset")
plt.ylabel("residuals[mas]")
plt.xlabel("epoch-2017[yr]")

plt.grid()gaia
plt.show()

plt.figure(figsize=(10,2))
plt.scatter(relative_time,res_gaia_final,c="k")
plt.axhline(0,linestyle="--")
plt.title("residuals")
plt.ylabel("O-C[mas]")
plt.xlabel("epoch-2017[yr]")

plt.grid()
plt.show()

# %% [markdown]
# # Combined fit of RVs and Gaia astrometry

# %%
def L_gaia_rv(theta,rvs,gaia_ad,gaia_stand):
    P,e,om,i,Om,T0,a=theta[:7]
    correction=theta[7:12]
    v0=theta[-1]

    t,data,err=rvs




    c_parallax=gaia_stand[2]+correction[2]

    

    Lg=ex.L_gaia(gaia_ad,correction, P, e, om, i, Om, T0, a)

    Lr=ex.L_RVs_comb(t, data, err, 0,v0, P, e, om, i, T0, a, c_parallax)
    
    

    return Lg+Lr

# %%
#units

rvmod=np.copy(rv)
rvmod[1:]=rvmod[1:]*1000

v0_g=np.array([-359.26*1000])
testtheta=np.concatenate((fit.x,v0_g))

# %%
#bounds
orbbnds=(P_g-100,P_g+100),(0,0.95),(-np.pi,np.pi),(0,2*np.pi),(-np.pi,np.pi),(T0_g-10000,T0_g+10000),(0,100)
standbnds=(-10,10),(-10,10),(-10,10),(-10,10),(-10,10)
v0_bnds=(v0_g-1e5,v0_g+1e5),
bnds=orbbnds+standbnds+v0_bnds

# %%
fit_combined=minimize(L_gaia_rv,testtheta,args=(rvmod,res_astrometric,g_stand),bounds=bnds,tol=1e-10,method="Nelder-mead",options={"maxiter":1e5})
print(fit_combined)
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -243.36518436534377
#              x: [ 4.211e+03  7.270e-01 ... -6.549e+00 -3.572e+05]
#            nit: 6755
#           nfev: 9424
#  final_simplex: (array([[ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05],
#                        [ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05],
#                        ...,
#                        [ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05],
#                        [ 4.211e+03,  7.270e-01, ..., -6.549e+00,
#                         -3.572e+05]], shape=(14, 13)), array([-2.434e+02, -2.434e+02, ..., -2.434e+02, -2.434e+02],
#                       shape=(14,)))

# %%
rvcombined=ex.RV_comb(fit_combined.x[-1],*fit_combined.x[:4],*fit_combined.x[5:7],g_stand[2],t_rvmod)

# %%
plt.plot(t_rvmod,rvcombined,c="k")
plt.scatter(rv[0],rv[1]*1000,c="r")
plt.errorbar(rv[0],rv[1]*1000,rv[2]*1000,linestyle="",c="k")
plt.axhline(fit_combined.x[-1],c="b",linestyle="--")
plt.grid()
plt.show()

# %%
rv_res=rvmod[1]-ex.RV_comb(fit_combined.x[-1],*fit_combined.x[:4],*fit_combined.x[5:7],g_stand[2],rv[0])

plt.scatter(rv[0],rv_res,c="r")
plt.errorbar(rv[0],rv_res,rv[2]*1000,c="k",linestyle="")
plt.axhline(0,c="b",linestyle="--")
plt.show()

# %%
fit_residuals=ex.abs_res(planet_residual,fit_combined.x[-6:-1],np.zeros(5),gaia)

x_O,y_O=ex.orbit(*fit_combined.x[:7],t_gaia)
    
res_gaia_final=fit_residuals-(A3*x_O+A4*y_O)

residual_to_orbit=ex.res_to_orbit_gaia(res_gaia_final,gaia, fit_combined.x[:7])



plt.title("residuals")
plt.ylabel("DEC[mas]")
plt.xlabel("RA[mas]")
plt.scatter(0,0,c="k",marker="x")

ex.plot_hip_err(*residual_to_orbit)
plt.plot(*ex.orbit(*fit_combined.x[:7],t_rvmod),c="k")



plt.gca().invert_xaxis()
plt.axis("equal")
plt.grid()

# %% [markdown]
# # Plotting with standard model

# %%
#correcting the standard model

t_rvmod=np.linspace(t_gaia[0],t_gaia[-1],1000)
stand_correction=fit_combined.x[7:12] #from fit
stand_updated=ex.stand_correct(g_stand,stand_correction) #correcting function

#orbital model
#data timestamps
x_O,y_O=ex.orbit(*fit_combined.x[:7],t_gaia)
#model timestamps
orbital_model=ex.orbit(*fit_combined.x[:7],t_rvmod)


#standard model
#data timestamps
earth_pos=ex.earth_position(t_gaia)
x_S,y_S=ex.standard_model(*stand_updated,t_gaia,earth_pos,Sepoch=ex.J2017(),tangential=True) 
#model timestamps
earth_pos_model=ex.earth_position(t_rvmod)
stand_model=ex.standard_model(*stand_updated,t_rvmod,earth_pos_model,Sepoch=ex.J2017(),tangential=True)


#adding the models
#model timestamps
total_model=np.array(stand_model)+np.array(orbital_model)

#data timestamps
total_motion=np.copy(residual_to_orbit)#copies residuals to orbit from last plot, then adds standard model on top
total_motion[0]=residual_to_orbit[0]+x_S#asc
total_motion[2]=residual_to_orbit[2]+y_S#dec



#plotting
plt.plot(*total_model,c="k")
ex.plot_hip_err(*total_motion,s=3)



pure=ex.standard_model(*g_stand,t_rvmod,earth_pos_model,Sepoch=ex.J2017(),tangential=True)





plt.title("total motion")
plt.ylabel("DEC[mas]")
plt.xlabel("RA[mas]")
plt.gca().invert_xaxis()
#plt.axis("equal")
plt.xlim([75,-75])
plt.ylim([-400,400])
plt.plot(*pure,c="b",linestyle="--")
plt.grid()
