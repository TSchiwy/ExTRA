# %%
import ExTRA as ex
from astropy.io import fits
from astropy.time import Time
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.optimize import minimize
# Out:
# ExTRA  imported correctly

# %%
ra=209.5063268875399
ra_err=0.0129
dec=31.695499700479004
dec_err=0.0125
plx=13.5448 
plx_err=0.0208
mu_asc=-75.412
mu_asc_err=0.020
mu_dec=18.063 
mu_dec_err=0.016

# %%
from astropy.table import Table
Table.read("data/Gaia4/gaia4_ast.dat",format="ascii")
# Out:
# <Table length=960>
#   col1    col2         col3        ...         col6                col7
# float64 float64      float64       ...       float64             float64
# ------- ------- ------------------ ... ------------------- -------------------
#     0.0     0.0  2457383.949563602 ... -114.54512922856426 0.11282999068498611
#     0.0     0.0  2457383.949687421 ... -114.74072467157701 0.11317567527294159
#     0.0     0.0 2457383.9497345565 ... -114.56288199959417 0.07482258230447769
#     0.0     0.0 2457383.9497908065 ... -114.83879863257579  0.0725749209523201
#     0.0     0.0  2457383.949847054 ... -114.73129669493154 0.07217571139335632
#     0.0     0.0 2457383.9499123683 ... -114.69947600587945 0.07198027521371841
#     0.0     0.0 2457383.9499686155 ... -114.79757103168077 0.08046172559261322
#     0.0     0.0 2457383.9500248637 ... -114.85975936264998 0.08243876695632935
#     0.0     0.0 2457383.9500811114 ... -114.71793922488284 0.06940563023090363
#     ...     ...                ... ...                 ...                 ...
#     0.0     0.0  2458608.028767054 ...  -94.17986755267991 0.09868927299976349
#     0.0     0.0 2458608.0288957106 ...  -92.03677336371324 0.09156199544668198
#     0.0     0.0  2458608.028951913 ...  -92.07802137566425 0.08547192811965942
#     0.0     0.0  2458608.029003313 ...  -92.15026630468226 0.07847601175308228
#     0.0     0.0  2458608.029064406 ...  -92.26396657770064  0.0839843824505806
#     0.0     0.0   2458608.02911581 ...   -92.2673025745874 0.06771747022867203
#     0.0     0.0 2458608.0291720578 ...  -92.25930380006567 0.07659804075956345
#     0.0     0.0  2458608.029228308 ...  -91.98669311256234 0.08275363594293594
#     0.0     0.0 2458608.0292893993 ...  -92.06956551186393  0.0753999799489975
#     0.0     0.0 2458608.0293407687 ...  -92.33353748393773 0.06225355714559555

# %%
gaia,t_gaia=ex.gaia_init(ast)
A3,A4,A5,A6,A7,A8,A9=gaia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 gaia,t_gaia=ex.gaia_init(ast)
#       2 A3,A4,A5,A6,A7,A8,A9=gaia
#
# NameError: name 'ast' is not defined

# %%
# Out:
# Signature: ex.hip_read(path)
# Docstring: Returns HIP astrometric data and time for hip measurements in a array
# File:      ~/ExTRA/ExTRA/read.py
# Type:      function
