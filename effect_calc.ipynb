# %%
import numpy as np 
import math
import astropy
import scipy.constants

# %%
lightyear=scipy.constants.c /1000 *365*24*60*60#km

# %%
v=14.45 #kms
parallax=18.5493 #mas
propmotion_asc=412.242 #mas/yr


covered_distance=v*(2017.0-1991.25)*365*24*60*60 / lightyear

delta_mas=propmotion_asc*covered_distance
print(delta_mas)
# Out:
# 0.511654283094073

# %%
def lighttimedifference(v,prop):


    lightyear=scipy.constants.c /1000 *365*24*60*60#km
    covered_dist=v*(2017-1991.25)*365.25*24*60*60 /lightyear

    delta=covered_dist*prop

    return delta #mas

# %%
lighttimedifference(16,300)/25 *1.5
# Out:
# 0.024754056528182557

# %%
def mu_r(v,para):

    mu_r=v*para*  24*np.pi*365.25/(180*scipy.constants.au)

    return mu_r

# %%
mu_r(v,parallax)
# Out:
# 2.7412509432653647e-07

# %%
scipy.constants.au/(365.25*24*60*60) /1000
# Out:
# 4.740470463533348

# %%
(1000*365.25*24*60*60/(scipy.constants.au))**-1
# Out:
# 4.740470463533349
